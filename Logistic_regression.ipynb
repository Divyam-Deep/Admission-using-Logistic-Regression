# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyam-Deep/Admission-using-Logistic-Regression/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
sns.set()

# %%
data = pd.read_csv('/content/2.02.+Binary+predictors.csv')
data.head()
# Out:
#     SAT Admitted  Gender
# 0  1363       No    Male
# 1  1792      Yes  Female
# 2  1954      Yes  Female
# 3  1653       No    Male
# 4  1593       No    Male

# %%
data['Admitted'] = data.Admitted.map({'Yes':1,'No':0})
data['Gender'] = data.Gender.map({'Male':0, 'Female':1})
data.head()
# Out:
#     SAT  Admitted  Gender
# 0  1363         0       0
# 1  1792         1       1
# 2  1954         1       1
# 3  1653         0       0
# 4  1593         0       0

# %%
y = data['Admitted']
x1 = data['Gender']

# %%
x = sm.add_constant(x1)
log_reg = sm.Logit(y,x)
result_log = log_reg.fit()
result_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.572260
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      166
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 02 Dec 2024   Pseudo R-squ.:                  0.1659
# Time:                        09:45:24   Log-Likelihood:                -96.140
# converged:                       True   LL-Null:                       -115.26
# Covariance Type:            nonrobust   LLR p-value:                 6.283e-10
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
np.exp(2.0786)
# Out:
# 7.993270498536442

# %%
y = data['Admitted']
x1 = data[['SAT','Gender']]

# %%
x = sm.add_constant(x1)
log_reg = sm.Logit(y,x)
result_log = log_reg.fit()
result_log.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.120117
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      165
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 02 Dec 2024   Pseudo R-squ.:                  0.8249
# Time:                        09:45:24   Log-Likelihood:                -20.180
# converged:                       True   LL-Null:                       -115.26
# Covariance Type:            nonrobust   LLR p-value:                 5.118e-42
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
np.exp(1.9449)
# Out:
# 6.992932526814459

# %%
result_log.pred_table().astype(int)  #its a confusion matrix
# Out:
# array([[69,  5],
#        [ 4, 90]])

# %%
cm_pf = pd.DataFrame(result_log.pred_table())
cm_pf.columns = ['Predicted 0','Predicted 1']
cm_pf = cm_pf.rename(index={0:'Actual 0',1:'Actual 1'})
cm_pf
# Out:
#           Predicted 0  Predicted 1
# Actual 0         69.0          5.0
# Actual 1          4.0         90.0

# %%
cm = np.array(cm_pf)
accuracy_train = (cm[0,0]+cm[1,1])/cm.sum()
accuracy_train
# Out:
# 0.9464285714285714

# %%
Test = pd.read_csv('/content/2.03.+Test+dataset.csv')
Test.head()
# Out:
#     SAT Admitted  Gender
# 0  1323       No    Male
# 1  1725      Yes  Female
# 2  1762      Yes  Female
# 3  1777      Yes    Male
# 4  1665       No    Male

# %%
Test['Admitted'] = Test.Admitted.map({'Yes':1,'No':0})
Test['Gender'] = Test.Gender.map({'Male':0, 'Female':1})
Test.head()
# Out:
#     SAT  Admitted  Gender
# 0  1323         0       0
# 1  1725         1       1
# 2  1762         1       1
# 3  1777         1       0
# 4  1665         0       0

# %%
x
# Out:
#      const   SAT  Gender
# 0      1.0  1363       0
# 1      1.0  1792       1
# 2      1.0  1954       1
# 3      1.0  1653       0
# 4      1.0  1593       0
# ..     ...   ...     ...
# 163    1.0  1722       1
# 164    1.0  1750       0
# 165    1.0  1555       0
# 166    1.0  1524       0
# 167    1.0  1461       0
#
# [168 rows x 3 columns]

# %%
test_actual = Test['Admitted']
test_data = Test.drop(['Admitted'],axis=1)
test_data = sm.add_constant(test_data)
test_data.head()
# Out:
#    const   SAT  Gender
# 0    1.0  1323       0
# 1    1.0  1725       1
# 2    1.0  1762       1
# 3    1.0  1777       0
# 4    1.0  1665       0

# %%
def confusion_matrix(data,actual_values,model):
  pred_values = model.predict(data)
  bins = np.array([0,0.5,1])
  cm = np.histogram2d(actual_values,pred_values,bins=bins)[0]
  accuracy = (cm[0,0]+cm[1,1])/cm.sum()
  return cm,accuracy

# %%
cm = confusion_matrix(test_data,test_actual,result_log)
cm
# Out:
# (array([[ 5.,  1.],
#         [ 1., 12.]]),
#  0.8947368421052632)
